# %% [markdown]
# # 🚀 VEC边缘计算迁移与缓存系统 - Kaggle训练
#
# ## ⚙️ 使用前准备
# 1. 右侧设置面板选择 **GPU P100** 或 **GPU T4**
# 2. 开启 **Internet**
# 3. 添加你上传的项目Dataset

# %% [markdown]
# ## 📦 第1步：加载项目代码

# %%
import shutil
import os

# 修改这里：替换为你的Dataset路径
dataset_path = '/kaggle/input/vec-migration-caching'  # ← 修改
work_path = '/kaggle/working/VEC_mig_caching'

if os.path.exists(work_path):
    shutil.rmtree(work_path)
shutil.copytree(dataset_path, work_path)
os.chdir(work_path)
print(f'✅ 项目加载完成: {os.getcwd()}')

# %% [markdown]
# ## 🔧 第2步：配置环境

# %%
# !pip install flask-socketio -q
# !mkdir -p results/single_agent/{td3,ddpg,sac,ppo,dqn}
# !mkdir -p academic_figures
print('✅ 环境配置完成')

# %%
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 🎯 第3步：开始训练

# %%
# 快速测试（50轮，约10分钟）
# !python kaggle_train.py --quick

# %%
# 标准训练（200轮，约40分钟）
# !python kaggle_train.py --standard

# %%
# 或直接使用训练脚本
# !python train_single_agent.py --algorithm TD3 --episodes 200 --seed 42

# %% [markdown]
# ## 📊 第4步：查看结果

# %%
# !ls -lh results/single_agent/*/training_results_*.json

# %% [markdown]
# ## 💾 第5步：保存结果

# %%
from datetime import datetime
import shutil
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
shutil.make_archive(f'results_{timestamp}', 'zip', 'results')
print(f'✅ 结果已打包，可在Output中下载')
